# %% [markdown]
# # Visualizing the Gender Gap in College Degrees

# %% [markdown]
# In this project, we'll visualise the gender gap in college degrees based on data from the Department of Education Statistics in the US. This dataset contains the percentage of Bachelor's degrees granted to women from 1970 to 2012. The data set is broken up into 17 categories of degrees, with each column as a separate category.
#
# We'll explore how we can communicate the nuanced narrative of gender gap using effective data visualisation. We'll also explore how to export the final diagram we create as an image file. This project will focus primarily on the aesthetics of the plots.

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')

# %%
# Create 3 different categories for degrees in the dataset, these lists are ordered in descending 
# order by the percentage of degrees awarded to women.
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

# %%
# Add the distinction of color for the graph 
cb_dark_blue = (0/255, 107/255, 164/255)
cb_orange = (255/255, 128/255, 14/255)

fig = plt.figure(figsize=(18, 20))

# Generate the first column of charts for STEM degrees. 
for sp in range(0, 6):
    # 17 plots in total so we need to have 6 rows and 3 columns format for the plots. 
    ax = fig.add_subplot(6, 3, 3 * sp+1)
    
    # Add the data to which we are graphing
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c= cb_dark_blue, linewidth=3, label='Women')
    ax.plot(women_degrees['Year'], 100- women_degrees[stem_cats[sp]], c= cb_orange, linewidth=3, label='Men')
    
    # Remove the spines from the plots
    for key, spine in ax.spines.items():
        spine.set_visible(False)
    
    # Remove the tick marks from the plot
    ax.tick_params(bottom=False, top=False, left=False, right=False)
    
    # Set x, y limits
    ax.set_xlim(1968, 2011)
    ax.set_ylim([0, 100])
    
    # Set y tick values to show only 0 and 100
    ax.set_yticks([0, 100])
    
    # Add a horizontal line at y = 50 position, with a transperancy of 0.3 and a light gray colour in the Colour Blind 10 palette
    ax.axhline(50, c = (171/255, 171/255, 171/255), alpha = 0.3)
    
    # Set title of each plot
    ax.set_title(stem_cats[sp])
    
    # Enable x-axis labels for the bottommost line chart in the STEM columns
    if sp == 5:
        ax.tick_params(labelbottom = True)
    else:
        ax.tick_params(labelbottom = False)
    
    #add text to the plot at a certain position
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')

## 2. Generate second column of charts for LIberal Arts degrees
for sp in range(0, 5):
    ax = fig.add_subplot(6, 3, 3 * sp + 2)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], c= cb_dark_blue, linewidth=3, label='Women')
    ax.plot(women_degrees['Year'], 100- women_degrees[lib_arts_cats[sp]], c= cb_orange, linewidth=3, label='Men')
    
    # 2. Remove the spines from the plots
    for key, spine in ax.spines.items():
        spine.set_visible(False)
    
    # 2. Remove the tick marks from the plot
    ax.tick_params(bottom=False, top=False, left=False, right=False)
    
    # 2. Set x, y limits
    ax.set_xlim(1970, 2011)
    ax.set_ylim(0, 100)
    
    # 2. Set y tick values to show only 0 and 100
    ax.set_yticks([0, 100])
    
    # 2. Add a horizontal line at y = 50 position, with a transperancy of 0.3 and a light gray colour in the Colour Blind 10 palette
    ax.axhline(50, c = (171/255, 171/255, 171/255), alpha = 0.3)
    
    # 2. Set title of each plot
    ax.set_title(lib_arts_cats[sp])
    
    # 2. Enable x-axis labels for the bottommost line chart in the Liberal Arts columns
    if sp == 4:
        ax.tick_params(labelbottom = True)
    else:
        ax.tick_params(labelbottom = False)
    
    #2. Add text to the plots at given positions
    if sp == 0:
        ax.text(2003, 78, 'Women')
        ax.text(2005, 18, 'Men')
    elif cat_index == 4:
        ax.tick_params(labelbottom='on')
    
## 3. Generate third column of charts. Other degrees
for sp in range(0, 6):
    ax = fig.add_subplot(6, 3, 3 * sp + 3)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[sp]], c = cb_dark_blue, linewidth = 3, label = 'Women')
    ax.plot(women_degrees['Year'], 100 - women_degrees[other_cats[sp]], c = cb_orange, linewidth = 3, label = 'Men')
    
    # 3. Remove the spines from the plots
    for key, spine in ax.spines.items():
        spine.set_visible(False)
        
    # 3. Remove the tick marks from the plot    
    ax.tick_params(bottom = False, top = False, left = False, right = False)
    
    # 3. Set x, y limits
    ax.set_xlim(1970, 2011)
    ax.set_ylim(0, 100)
    
    # 3. Set y tick values to show only 0 and 100
    ax.set_yticks([0, 100])
    
    # 3. Add a horizontal line at y = 50 position, with a transperancy of 0.3 and a light gray colour in the Colour Blind 10 palette
    ax.axhline(50, c = (171/255, 171/255, 171/255), alpha = 0.3)
    
    # 3. Set title of each plot
    ax.set_title(other_cats[sp])
    
    # 3. Enable x-axis labels for the bottommost line chart in the Other degrees columns
    if sp == 5:
        ax.tick_params(labelbottom = True)
    else:
        ax.tick_params(labelbottom = False)

    # 3. Add text to the plots at given positions
    if sp == 0:
        ax.text(2008, 5, 'Men')
        ax.text(2005, 88, 'Women')
    elif sp == 5:
        ax.text(2008, 65, 'Men')
        ax.text(2005, 35, 'Women')
        
# Export the figure containing all the line charts.
plt.savefig('gender_degrees.png')

plt.show()

# %% [markdown]
# ### Discoveries:
#
# ### STEM Degrees:
# Starting from the top left going down the first column we can notice that women are a majority in the Psychology major. From the plots we can notice that Biology and Physical Sciences are gaining popularity over the time period of the dataset. There is a bery low gender gap between Math & Science degree during the time period. We can also notice that there is a considerable gender gap in Computer Science and Engineering degrees.
#
# ### Liberal Arts Degrees:
# From exploring the plots on Liberal Art degrees we can notice that women participate more in these majors then men. The line chart for Foreign Languages, English, and Art & Perfomance seem to make little to no change a long the timeframe. There are no gender gaps as time goes by for Social Sciences and History.
#
# ### Other Fields:
# The top 3 degrees (Health Professions, Public Administration, Education) are majority women in each of the fields.
# There is a correlation of popularity among Agriculture, Business, and Artecture degrees over time for women.
